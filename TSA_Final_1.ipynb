# %%
import pandas as pd
import csv
import sklearn
import re
import numpy as np
import nltk

# %%
data_train = pd.read_csv(r'C:\Academia\Sentiment Analysis Twitter\train.csv',engine='python',quoting=csv.QUOTE_NONE,sep='delimiter',error_bad_lines=False)

df = data_train

listsen = {'sentiment':[], 'sentimentText':[]}
for i in df['Sentiment,SentimentText']:
    sent = i[0]
    text = i[2:]
    listsen['sentiment'].append(sent)
    listsen['sentimentText'].append(text)
listsen
df1 = pd.DataFrame(listsen)  

frames = [df1, df]

result = pd.concat(frames, axis=1)
df2 = result.drop('Sentiment,SentimentText', axis=1)

df2
# Out:
#       sentiment                                      sentimentText
# 0             0                       is so sad for my APL frie...
# 1             0                     I missed the New Moon trail...
# 2             1                            omg its already 7:30 :O
# 3             0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4             0           i think mi bf is cheating on me!!!   ...
# 5             0                          or i just worry too much?
# 6             1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7             0         Sunny Again        Work Tomorrow  :-|  ...
# 8             1        handed in my uniform today . i miss you ...
# 9             1           hmmmm.... i wonder how she my number @-)
# 10            0                      I must think about positive..
# 11            1        thanks to all the haters up in my face a...
# 12            0                     this weekend has sucked so far
# 13            0             jb isnt showing in australia any more!
# 14            0                               ok thats it you win.
# 15            0      &lt;-------- This is the way i feel right ...
# 16            0  "    awhhe man.... I'm completely useless rt n...
# 17            1      Feeling strangely fine. Now I'm gonna go l...
# 18            0       HUGE roll of thunder just now...SO scary!!!!
# 19            0      I just cut my beard off. It's only been gr...
# 20            0                               Very sad about Iran.
# 21            0                                      wompppp wompp
# 22            1      You're the only one who can see this cause...
# 23            0     &lt;---Sad level is 3. I was writing a mass...
# 24            0     ...  Headed to Hospitol : Had to pull out o...
# 25            0     BoRinG   ): whats wrong with him??     Plea...
# 26            0     can't be bothered. i wish i could spend the...
# 27            0  "   Feeeling like shit right now. I really wan...
# 28            1         "   goodbye exams, HELLO ALCOHOL TONIGHT "
# 29            0     I didn't realize it was THAT deep. Geez giv...
# ...         ...                                                ...
# 99970         0  @CT415 @UCLA_Bruin  it made me sad too!  that ...
# 99971         1  @CT415 I agree. I think they all have that fet...
# 99972         0  @ct415 I hope it's not too serious of an injur...
# 99973         0  "@ctabita if it's any consolation, this weeken...
# 99974         1                      "@ctayah got your back, yo! "
# 99975         1  @ctaylor0127 I can't wait to see that movie. E...
# 99976         1  @ctaylor10127 @smelby I am excited and a littl...
# 99977         0  @ctb1221 yeah  sorry.going to a concert that n...
# 99978         1  @ctcash @buildingateam @diabetescure @chocolat...
# 99979         1  @ctdesign87 im so glad you went to china town ...
# 99980         0                                 @CTerry1985  Sorry
# 99981         0              "@CTerry1985 damn it, dont have sky "
# 99982         0  @CTerry1985 That's the thing; the new raft of ...
# 99983         1                                           @cthagod
# 99984         1                              @ctham  #FollowFriday
# 99985         0  "@ctham #awaresg You are not wrong. But from a...
# 99986         0  @ctham @mommyfizz cuz you big burly man.  haha...
# 99987         1  @ctham @Wilsurn Trying to get a wider range of...
# 99988         1     @ctham Haha I love the passion in your support
# 99989         1  "@cthulhullahoop That sucks...I like living in...
# 99990         1  @cunningstunts till i can go home been here ti...
# 99991         1         @cunningstunts22 afternoon jim hows you  x
# 99992         0  @cup_a_tea The foot is really bad. Like the wo...
# 99993         1  @Cup_Of_Katy Have fun doing health &amp; safet...
# 99994         0  @cupati It took me waaay too long to get your ...
# 99995         0  @Cupcake  seems like a repeating problem   hop...
# 99996         1  "@cupcake__ arrrr we both replied to each othe...
# 99997         0                      @CuPcAkE_2120 ya i thought so
# 99998         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99999         1                     @cupcake_kayla haha yes you do
#
# [100000 rows x 2 columns]
#       sentiment                                      sentimentText
# 0             0                       is so sad for my APL frie...
# 1             0                     I missed the New Moon trail...
# 2             1                            omg its already 7:30 :O
# 3             0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4             0           i think mi bf is cheating on me!!!   ...
# 5             0                          or i just worry too much?
# 6             1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7             0         Sunny Again        Work Tomorrow  :-|  ...
# 8             1        handed in my uniform today . i miss you ...
# 9             1           hmmmm.... i wonder how she my number @-)
# 10            0                      I must think about positive..
# 11            1        thanks to all the haters up in my face a...
# 12            0                     this weekend has sucked so far
# 13            0             jb isnt showing in australia any more!
# 14            0                               ok thats it you win.
# 15            0      &lt;-------- This is the way i feel right ...
# 16            0  "    awhhe man.... I'm completely useless rt n...
# 17            1      Feeling strangely fine. Now I'm gonna go l...
# 18            0       HUGE roll of thunder just now...SO scary!!!!
# 19            0      I just cut my beard off. It's only been gr...
# 20            0                               Very sad about Iran.
# 21            0                                      wompppp wompp
# 22            1      You're the only one who can see this cause...
# 23            0     &lt;---Sad level is 3. I was writing a mass...
# 24            0     ...  Headed to Hospitol : Had to pull out o...
# 25            0     BoRinG   ): whats wrong with him??     Plea...
# 26            0     can't be bothered. i wish i could spend the...
# 27            0  "   Feeeling like shit right now. I really wan...
# 28            1         "   goodbye exams, HELLO ALCOHOL TONIGHT "
# 29            0     I didn't realize it was THAT deep. Geez giv...
# ...         ...                                                ...
# 99970         0  @CT415 @UCLA_Bruin  it made me sad too!  that ...
# 99971         1  @CT415 I agree. I think they all have that fet...
# 99972         0  @ct415 I hope it's not too serious of an injur...
# 99973         0  "@ctabita if it's any consolation, this weeken...
# 99974         1                      "@ctayah got your back, yo! "
# 99975         1  @ctaylor0127 I can't wait to see that movie. E...
# 99976         1  @ctaylor10127 @smelby I am excited and a littl...
# 99977         0  @ctb1221 yeah  sorry.going to a concert that n...
# 99978         1  @ctcash @buildingateam @diabetescure @chocolat...
# 99979         1  @ctdesign87 im so glad you went to china town ...
# 99980         0                                 @CTerry1985  Sorry
# 99981         0              "@CTerry1985 damn it, dont have sky "
# 99982         0  @CTerry1985 That's the thing; the new raft of ...
# 99983         1                                           @cthagod
# 99984         1                              @ctham  #FollowFriday
# 99985         0  "@ctham #awaresg You are not wrong. But from a...
# 99986         0  @ctham @mommyfizz cuz you big burly man.  haha...
# 99987         1  @ctham @Wilsurn Trying to get a wider range of...
# 99988         1     @ctham Haha I love the passion in your support
# 99989         1  "@cthulhullahoop That sucks...I like living in...
# 99990         1  @cunningstunts till i can go home been here ti...
# 99991         1         @cunningstunts22 afternoon jim hows you  x
# 99992         0  @cup_a_tea The foot is really bad. Like the wo...
# 99993         1  @Cup_Of_Katy Have fun doing health &amp; safet...
# 99994         0  @cupati It took me waaay too long to get your ...
# 99995         0  @Cupcake  seems like a repeating problem   hop...
# 99996         1  "@cupcake__ arrrr we both replied to each othe...
# 99997         0                      @CuPcAkE_2120 ya i thought so
# 99998         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99999         1                     @cupcake_kayla haha yes you do
#
# [100000 rows x 2 columns]

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt    

# remove twitter handles (@user)
df2['tidy_tweet'] = np.vectorize(remove_pattern)(df2['sentimentText'], "@[\w]*")

df2
# Out:
#       sentiment                                      sentimentText  \
# 0             0                       is so sad for my APL frie...
# 1             0                     I missed the New Moon trail...
# 2             1                            omg its already 7:30 :O
# 3             0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4             0           i think mi bf is cheating on me!!!   ...
# 5             0                          or i just worry too much?
# 6             1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7             0         Sunny Again        Work Tomorrow  :-|  ...
# 8             1        handed in my uniform today . i miss you ...
# 9             1           hmmmm.... i wonder how she my number @-)
# 10            0                      I must think about positive..
# 11            1        thanks to all the haters up in my face a...
# 12            0                     this weekend has sucked so far
# 13            0             jb isnt showing in australia any more!
# 14            0                               ok thats it you win.
# 15            0      &lt;-------- This is the way i feel right ...
# 16            0  "    awhhe man.... I'm completely useless rt n...
# 17            1      Feeling strangely fine. Now I'm gonna go l...
# 18            0       HUGE roll of thunder just now...SO scary!!!!
# 19            0      I just cut my beard off. It's only been gr...
# 20            0                               Very sad about Iran.
# 21            0                                      wompppp wompp
# 22            1      You're the only one who can see this cause...
# 23            0     &lt;---Sad level is 3. I was writing a mass...
# 24            0     ...  Headed to Hospitol : Had to pull out o...
# 25            0     BoRinG   ): whats wrong with him??     Plea...
# 26            0     can't be bothered. i wish i could spend the...
# 27            0  "   Feeeling like shit right now. I really wan...
# 28            1         "   goodbye exams, HELLO ALCOHOL TONIGHT "
# 29            0     I didn't realize it was THAT deep. Geez giv...
# ...         ...                                                ...
# 99970         0  @CT415 @UCLA_Bruin  it made me sad too!  that ...
# 99971         1  @CT415 I agree. I think they all have that fet...
# 99972         0  @ct415 I hope it's not too serious of an injur...
# 99973         0  "@ctabita if it's any consolation, this weeken...
# 99974         1                      "@ctayah got your back, yo! "
# 99975         1  @ctaylor0127 I can't wait to see that movie. E...
# 99976         1  @ctaylor10127 @smelby I am excited and a littl...
# 99977         0  @ctb1221 yeah  sorry.going to a concert that n...
# 99978         1  @ctcash @buildingateam @diabetescure @chocolat...
# 99979         1  @ctdesign87 im so glad you went to china town ...
# 99980         0                                 @CTerry1985  Sorry
# 99981         0              "@CTerry1985 damn it, dont have sky "
# 99982         0  @CTerry1985 That's the thing; the new raft of ...
# 99983         1                                           @cthagod
# 99984         1                              @ctham  #FollowFriday
# 99985         0  "@ctham #awaresg You are not wrong. But from a...
# 99986         0  @ctham @mommyfizz cuz you big burly man.  haha...
# 99987         1  @ctham @Wilsurn Trying to get a wider range of...
# 99988         1     @ctham Haha I love the passion in your support
# 99989         1  "@cthulhullahoop That sucks...I like living in...
# 99990         1  @cunningstunts till i can go home been here ti...
# 99991         1         @cunningstunts22 afternoon jim hows you  x
# 99992         0  @cup_a_tea The foot is really bad. Like the wo...
# 99993         1  @Cup_Of_Katy Have fun doing health &amp; safet...
# 99994         0  @cupati It took me waaay too long to get your ...
# 99995         0  @Cupcake  seems like a repeating problem   hop...
# 99996         1  "@cupcake__ arrrr we both replied to each othe...
# 99997         0                      @CuPcAkE_2120 ya i thought so
# 99998         1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99999         1                     @cupcake_kayla haha yes you do
#
#                                               tidy_tweet
# 0                           is so sad for my APL frie...
# 1                         I missed the New Moon trail...
# 2                                omg its already 7:30 :O
# 3                .. Omgaga. Im sooo  im gunna CRy. I'...
# 4               i think mi bf is cheating on me!!!   ...
# 5                              or i just worry too much?
# 6                     Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7             Sunny Again        Work Tomorrow  :-|  ...
# 8            handed in my uniform today . i miss you ...
# 9                hmmmm.... i wonder how she my number -)
# 10                         I must think about positive..
# 11           thanks to all the haters up in my face a...
# 12                        this weekend has sucked so far
# 13                jb isnt showing in australia any more!
# 14                                  ok thats it you win.
# 15         &lt;-------- This is the way i feel right ...
# 16     "    awhhe man.... I'm completely useless rt n...
# 17         Feeling strangely fine. Now I'm gonna go l...
# 18          HUGE roll of thunder just now...SO scary!!!!
# 19         I just cut my beard off. It's only been gr...
# 20                                  Very sad about Iran.
# 21                                         wompppp wompp
# 22         You're the only one who can see this cause...
# 23        &lt;---Sad level is 3. I was writing a mass...
# 24        ...  Headed to Hospitol : Had to pull out o...
# 25        BoRinG   ): whats wrong with him??     Plea...
# 26        can't be bothered. i wish i could spend the...
# 27     "   Feeeling like shit right now. I really wan...
# 28            "   goodbye exams, HELLO ALCOHOL TONIGHT "
# 29        I didn't realize it was THAT deep. Geez giv...
# ...                                                  ...
# 99970     it made me sad too!  that means no more albums
# 99971    I agree. I think they all have that fetish too!
# 99972   I hope it's not too serious of an injury!  I'...
# 99973  " if it's any consolation, this weekend isnt q...
# 99974                             " got your back, yo! "
# 99975              I can't wait to see that movie. Enjoy
# 99976    I am excited and a little nervous. I can't wait
# 99977   yeah  sorry.going to a concert that night.non...
# 99978      = Thanks for spreading the word for #Diabe...
# 99979   im so glad you went to china town again  i ac...
# 99980                                              Sorry
# 99981                         " damn it, dont have sky "
# 99982   That's the thing; the new raft of Star Wars f...
# 99983
# 99984                                      #FollowFriday
# 99985  " #awaresg You are not wrong. But from a my ow...
# 99986         cuz you big burly man.  hahahahahahahahaha
# 99987    Trying to get a wider range of shirts to sui...
# 99988            Haha I love the passion in your support
# 99989  " That sucks...I like living in Coopersville, ...
# 99990      till i can go home been here till saturday  x
# 99991                          afternoon jim hows you  x
# 99992   The foot is really bad. Like the worst it's e...
# 99993   Have fun doing health &amp; safety :S Just sw...
# 99994   It took me waaay too long to get your message...
# 99995    seems like a repeating problem   hope you're...
# 99996  " arrrr we both replied to each other over dif...
# 99997                                    ya i thought so
# 99998       Yes. Yes. I'm glad you had more fun with me.
# 99999                                    haha yes you do
#
# [100000 rows x 3 columns]

# %%
# remove special characters, numbers, punctuations
df2['tidy_tweet'] = df2['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")

for i in range(len(df2.index)):
    df2['tidy_tweet'][i] = re.sub(r'\b\w{1,2}\b', '', df2['tidy_tweet'][i])
    df2['tidy_tweet'][i] = re.sub(r'\s\s+', ' ', df2['tidy_tweet'][i])
    df2['tidy_tweet'][i] = df2['tidy_tweet'][i].lstrip(' ') 

df2
temp = df2

# %%
tokenized_tweet = df2['tidy_tweet'].apply(lambda x: x.split())

from nltk.stem.porter import *
from nltk.corpus import stopwords
stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])        # stemming

for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
    
df2['tidy_tweet'] = tokenized_tweet

for i in range(len(df2.index)):
    tweet = df2['tidy_tweet'][i] 
    tweet = tweet.split()
    tweet = [stemmer.stem(word) for word in tweet if not word in set(stopwords.words('english'))]
    tweet = ' '.join(tweet)
    df2['tidy_tweet'][i] = tweet

df2.sentiment = pd.to_numeric(df2.sentiment)
df2
# Out:
#        sentiment                                      sentimentText  \
# 0              0                       is so sad for my APL frie...
# 1              0                     I missed the New Moon trail...
# 2              1                            omg its already 7:30 :O
# 3              0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4              0           i think mi bf is cheating on me!!!   ...
# 5              0                          or i just worry too much?
# 6              1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7              0         Sunny Again        Work Tomorrow  :-|  ...
# 8              1        handed in my uniform today . i miss you ...
# 9              1           hmmmm.... i wonder how she my number @-)
# 10             0                      I must think about positive..
# 11             1        thanks to all the haters up in my face a...
# 12             0                     this weekend has sucked so far
# 13             0             jb isnt showing in australia any more!
# 14             0                               ok thats it you win.
# 15             0      &lt;-------- This is the way i feel right ...
# 16             0  "    awhhe man.... I'm completely useless rt n...
# 17             1      Feeling strangely fine. Now I'm gonna go l...
# 18             0       HUGE roll of thunder just now...SO scary!!!!
# 19             0      I just cut my beard off. It's only been gr...
# 20             0                               Very sad about Iran.
# 21             0                                      wompppp wompp
# 22             1      You're the only one who can see this cause...
# 23             0     &lt;---Sad level is 3. I was writing a mass...
# 24             0     ...  Headed to Hospitol : Had to pull out o...
# 25             0     BoRinG   ): whats wrong with him??     Plea...
# 26             0     can't be bothered. i wish i could spend the...
# 27             0  "   Feeeling like shit right now. I really wan...
# 28             1         "   goodbye exams, HELLO ALCOHOL TONIGHT "
# 29             0     I didn't realize it was THAT deep. Geez giv...
# ...          ...                                                ...
# 99970          0  @CT415 @UCLA_Bruin  it made me sad too!  that ...
# 99971          1  @CT415 I agree. I think they all have that fet...
# 99972          0  @ct415 I hope it's not too serious of an injur...
# 99973          0  "@ctabita if it's any consolation, this weeken...
# 99974          1                      "@ctayah got your back, yo! "
# 99975          1  @ctaylor0127 I can't wait to see that movie. E...
# 99976          1  @ctaylor10127 @smelby I am excited and a littl...
# 99977          0  @ctb1221 yeah  sorry.going to a concert that n...
# 99978          1  @ctcash @buildingateam @diabetescure @chocolat...
# 99979          1  @ctdesign87 im so glad you went to china town ...
# 99980          0                                 @CTerry1985  Sorry
# 99981          0              "@CTerry1985 damn it, dont have sky "
# 99982          0  @CTerry1985 That's the thing; the new raft of ...
# 99983          1                                           @cthagod
# 99984          1                              @ctham  #FollowFriday
# 99985          0  "@ctham #awaresg You are not wrong. But from a...
# 99986          0  @ctham @mommyfizz cuz you big burly man.  haha...
# 99987          1  @ctham @Wilsurn Trying to get a wider range of...
# 99988          1     @ctham Haha I love the passion in your support
# 99989          1  "@cthulhullahoop That sucks...I like living in...
# 99990          1  @cunningstunts till i can go home been here ti...
# 99991          1         @cunningstunts22 afternoon jim hows you  x
# 99992          0  @cup_a_tea The foot is really bad. Like the wo...
# 99993          1  @Cup_Of_Katy Have fun doing health &amp; safet...
# 99994          0  @cupati It took me waaay too long to get your ...
# 99995          0  @Cupcake  seems like a repeating problem   hop...
# 99996          1  "@cupcake__ arrrr we both replied to each othe...
# 99997          0                      @CuPcAkE_2120 ya i thought so
# 99998          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99999          1                     @cupcake_kayla haha yes you do
#
#                                               tidy_tweet
# 0                                         sad apl friend
# 1                                  miss new moon trailer
# 2                                            omg alreadi
# 3      omgaga sooo gunna cri thi dentist sinc wa supo...
# 4                                            think cheat
# 5                                             worri much
# 6                       juuuuuuuuuuuuuuuuussssst chillin
# 7                            sunni work tomorrow tonight
# 8                        hand uniform today miss alreadi
# 9                                    hmmmm wonder number
# 10                                      must think posit
# 11                                  thank hater face day
# 12                               thi weekend ha suck far
# 13                               isnt show australia ani
# 14                                                   win
# 15                                    thi way feel right
# 16     awhh man complet useless funni twitter http myloc
# 17          feel strang fine gonna listen semison celebr
# 18                               huge roll thunder scari
# 19     cut beard onli grow well year gonna start happ...
# 20                                         veri sad iran
# 21                                         wompppp wompp
# 22     onli one see thi cau one el follow thi becau p...
# 23     sad level wa write massiv blog tweet myspac co...
# 24     head hospitol pull golf tourni place think rip...
# 25                                  bore wrong plea tell
# 26     bother wish could spend rest life sat go gig s...
# 27     feeel like shit right realli want sleep nooo h...
# 28                     goodbi exam hello alcohol tonight
# 29            realiz wa deep geez give girl warn atleast
# ...                                                  ...
# 99970                                made sad mean album
# 99971                                   agr think fetish
# 99972     hope seriou injuri worri take relax bath tonit
# 99973  ani consol thi weekend isnt quit wa expect either
# 99974                                           got back
# 99975                                wait see movi enjoy
# 99976                            excit littl nervou wait
# 99977      yeah sorri go concert night non return ticket
# 99978          thank spread word #diabet #spain http bit
# 99979  glad went china town actual think biryani plac...
# 99980                                              sorri
# 99981                                      damn dont sky
# 99982        thing new raft star war film raft #epicfail
# 99983
# 99984                                      #followfriday
# 99985  #awaresg wrong male point view felt exclud eve...
# 99986               cuz big burli man hahahahahahahahaha
# 99987  tri get wider rang shirt suit everyon plea mak...
# 99988                          haha love passion support
# 99989   suck like live coopersvil need special bag anyth
# 99990                            till home till saturday
# 99991                                      afternoon jim
# 99992    foot realli bad like worst ever bare walk right
# 99993       fun health amp safeti switch look sprite xxx
# 99994  took waaay long get messag asham right realli ...
# 99995      seem like repeat problem hope abl find someth
# 99996  arrrr repli differ tweet time see duno hell ka...
# 99997                                            thought
# 99998                                     ye ye glad fun
# 99999                                            haha ye
#
# [100000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

all_words = ' '.join([text for text in temp['tidy_tweet']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

df3 = temp[temp.sentiment != 1]
df4 = temp[temp.sentiment != 0]

z =' '.join([text for text in df3['tidy_tweet']])

wordcloud0 = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(z)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud0, interpolation="bilinear")
plt.axis('off')
plt.show()


one = ' '.join([text for text in df4['tidy_tweet']])

wordcloud1 = WordCloud(width=800, height=500,
random_state=21, max_font_size=110).generate(one)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud1, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')

# BAG-OF-WORDS feature matrix
bow = bow_vectorizer.fit_transform(df2['tidy_tweet']).toarray()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')

# TF-IDF feature matrix
tfidf = tfidf_vectorizer.fit_transform(df2['tidy_tweet']).toarray()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

Y = df2.iloc[:,0].values

X_train_bow,X_test_bow,Y_train,Y_test = train_test_split(bow,Y,test_size = 0.20,random_state = 1)
X_train_tfidf,X_test_tfidf,Y_train,Y_test = train_test_split(tfidf,Y,test_size = 0.20,random_state = 1)

# %%
# LOGISTIC REG. BOW


classifier = LogisticRegression(random_state = 1)
classifier.fit(X_train_bow,Y_train)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=1, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
Y_pred_LR_bow = classifier.predict(X_test_bow)
cm_LR_bow = confusion_matrix(Y_test,Y_pred_LR_bow)
LR_accuracy_bow = (cm_LR_bow[0,0]+cm_LR_bow[1,1])/(cm_LR_bow[0,0]+cm_LR_bow[0,1]+cm_LR_bow[1,0]+cm_LR_bow[1,1])
LR_precision_bow = cm_LR_bow[1,1]/(cm_LR_bow[0,1]+cm_LR_bow[1,1])
LR_recall_bow = cm_LR_bow[1,1]/(cm_LR_bow[1,0]+cm_LR_bow[1,1])
LR_f1_score_bow = 2*(LR_precision_bow*LR_recall_bow)/(LR_precision_bow+LR_recall_bow)

# %%
# LOGISTIC REG. TF-IDF


classifier.fit(X_train_tfidf,Y_train)
Y_pred_LR_tfidf = classifier.predict(X_test_tfidf)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
cm_LR_tfidf = confusion_matrix(Y_test,Y_pred_LR_tfidf)
LR_precision_tfidf = cm_LR_tfidf[1,1]/(cm_LR_tfidf[0,1]+cm_LR_tfidf[1,1])
LR_recall_tfidf = cm_LR_tfidf[1,1]/(cm_LR_tfidf[1,0]+cm_LR_tfidf[1,1])
LR_f1_score_tfidf = 2*(LR_precision_tfidf*LR_recall_tfidf)/(LR_precision_tfidf+LR_recall_tfidf)
LR_accuracy_tfidf = (cm_LR_tfidf[0,0]+cm_LR_tfidf[1,1])/(cm_LR_tfidf[0,0]+cm_LR_tfidf[0,1]+cm_LR_tfidf[1,0]+cm_LR_tfidf[1,1])

# %%
#Naive-Bayes BOW

NBclassifier = GaussianNB()

NBclassifier.fit(X_train_bow,Y_train)
Y_pred_NB_bow = NBclassifier.predict(X_test_bow)
cm_NB_bow = confusion_matrix(Y_test,Y_pred_NB_bow)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

nb_accuracy_bow = format(accuracy_score(Y_test, Y_pred_NB_bow))
nb_precision_bow = format(precision_score(Y_test, Y_pred_NB_bow, average=None))
nb_recall_bow = format(recall_score(Y_test, Y_pred_NB_bow,average=None))
nb_f1_score_bow = format(f1_score(Y_test, Y_pred_NB_bow,average=None))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
#Naive-Bayes TF-IDF

NBclassifier.fit(X_train_tfidf,Y_train)
Y_pred_NB_tfidf = NBclassifier.predict(X_test_tfidf)
cm_NB_tfidf = confusion_matrix(Y_test,Y_pred_NB_tfidf)

# %%
nb_accuracy_tfidf = format(accuracy_score(Y_test, Y_pred_NB_tfidf))
nb_precision_tfidf = format(precision_score(Y_test, Y_pred_NB_tfidf, average=None))
nb_recall_tfidf = format(recall_score(Y_test, Y_pred_NB_tfidf,average=None))
nb_f1_score_tfidf = format(f1_score(Y_test, Y_pred_NB_tfidf,average=None))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
#NN-BOW

import keras
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dense
from keras import backend as K

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    precision = true_positives / (predicted_positives + K.epsilon())
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

classifierbow = Sequential()
classifierbow.add(Dense(activation="relu", input_dim=1000, units=500, kernel_initializer="uniform"))
classifierbow.add(Dense(activation="relu", units=250, kernel_initializer="uniform"))
classifierbow.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))
classifierbow.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy', recall, precision, f1])
hist = classifierbow.fit(X_train_bow, Y_train, batch_size = 32, epochs = 10)

y_pred_nn_bow = classifierbow.predict(X_test_bow)
nn_accuracy_bow = hist.history['acc']
nn_precision_bow = hist.history['recall']
nn_recall_bow = hist.history['precision']
nn_f1_score_bow = hist.history['f1']
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 80000/80000 [==============================] - 23s 283us/step - loss: 0.5479 - acc: 0.7174 - recall: 0.8123 - precision: 0.7230 - f1: 0.7591
# Epoch 2/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.5086 - acc: 0.7463 - recall: 0.8285 - precision: 0.7492 - f1: 0.7822
# Epoch 3/10
# 80000/80000 [==============================] - 23s 282us/step - loss: 0.4383 - acc: 0.7869 - recall: 0.8489 - precision: 0.7903 - f1: 0.8138
# Epoch 4/10
# 80000/80000 [==============================] - 23s 283us/step - loss: 0.3118 - acc: 0.8506 - recall: 0.8927 - precision: 0.8504 - f1: 0.8677
# Epoch 5/10
# 80000/80000 [==============================] - 23s 281us/step - loss: 0.2167 - acc: 0.8936 - recall: 0.9293 - precision: 0.8882 - f1: 0.9058
# Epoch 6/10
# 80000/80000 [==============================] - 23s 281us/step - loss: 0.1688 - acc: 0.9146 - recall: 0.9466 - precision: 0.9068 - f1: 0.9243
# Epoch 7/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.1461 - acc: 0.9230 - recall: 0.9544 - precision: 0.9140 - f1: 0.9320
# Epoch 8/10
# 80000/80000 [==============================] - 23s 281us/step - loss: 0.1348 - acc: 0.9282 - recall: 0.9593 - precision: 0.9173 - f1: 0.9361
# Epoch 9/10
# 80000/80000 [==============================] - 22s 281us/step - loss: 0.1243 - acc: 0.9325 - recall: 0.9642 - precision: 0.9206 - f1: 0.9404
# Epoch 10/10
# 80000/80000 [==============================] - 23s 282us/step - loss: 0.1183 - acc: 0.9351 - recall: 0.9674 - precision: 0.9220 - f1: 0.9426

# %%
#NN-TF-IDF

classifiertf = Sequential()
classifiertf.add(Dense(activation="relu", input_dim=1000, units=500, kernel_initializer="uniform"))
classifiertf.add(Dense(activation="relu", units=250, kernel_initializer="uniform"))
classifiertf.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))
classifiertf.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy', recall, precision, f1])
hist1 = classifiertf.fit(X_train_tfidf, Y_train, batch_size = 32, epochs = 10)

y_pred_nn_tfidf = classifiertf.predict(X_test_tfidf)
nn_accuracy_tfidf = hist1.history['acc']
nn_precision_tfidf = hist1.history['recall']
nn_recall_tfidf = hist1.history['precision']
nn_f1_score_tfidf = hist1.history['f1']
# Out:
# Epoch 1/10
# 80000/80000 [==============================] - 23s 285us/step - loss: 0.5451 - acc: 0.7160 - recall: 0.8093 - precision: 0.7245 - f1: 0.7579
# Epoch 2/10
# 80000/80000 [==============================] - 22s 277us/step - loss: 0.5153 - acc: 0.7395 - recall: 0.8252 - precision: 0.7423 - f1: 0.7767
# Epoch 3/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.4772 - acc: 0.7671 - recall: 0.8360 - precision: 0.7711 - f1: 0.7976
# Epoch 4/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.3782 - acc: 0.8241 - recall: 0.8746 - precision: 0.8255 - f1: 0.8455
# Epoch 5/10
# 80000/80000 [==============================] - 23s 284us/step - loss: 0.2600 - acc: 0.8745 - recall: 0.9157 - precision: 0.8698 - f1: 0.8892
# Epoch 6/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.1901 - acc: 0.9024 - recall: 0.9420 - precision: 0.8918 - f1: 0.9139
# Epoch 7/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.1562 - acc: 0.9181 - recall: 0.9559 - precision: 0.9051 - f1: 0.9279
# Epoch 8/10
# 80000/80000 [==============================] - 22s 279us/step - loss: 0.1383 - acc: 0.9258 - recall: 0.9612 - precision: 0.9122 - f1: 0.9343
# Epoch 9/10
# 80000/80000 [==============================] - 22s 281us/step - loss: 0.1274 - acc: 0.9305 - recall: 0.9636 - precision: 0.9180 - f1: 0.9386
# Epoch 10/10
# 80000/80000 [==============================] - 22s 280us/step - loss: 0.1203 - acc: 0.9335 - recall: 0.9659 - precision: 0.9207 - f1: 0.9412

# %%
# Gradient Boosting Classifier

from sklearn.ensemble import GradientBoostingClassifier
gbk = GradientBoostingClassifier()

# %%
#BOW

gbk.fit(X_train_bow, Y_train)
Y_pred_gbk_bow = gbk.predict(X_test_bow)
cm_gbk_bow = confusion_matrix(Y_test,Y_pred_gbk_bow)
gbk_accuracy_bow = (cm_gbk_bow[0,0]+cm_gbk_bow[1,1])/(cm_gbk_bow[0,0]+cm_gbk_bow[0,1]+cm_gbk_bow[1,0]+cm_gbk_bow[1,1])
gbk_precision_bow = cm_gbk_bow[1,1]/(cm_gbk_bow[0,1]+cm_gbk_bow[1,1])
gbk_recall_bow = cm_gbk_bow[1,1]/(cm_gbk_bow[1,0]+cm_gbk_bow[1,1])
gbk_f1_score_bow = 2*(gbk_precision_bow*gbk_recall_bow)/(gbk_precision_bow+gbk_recall_bow)

# %%
#TF-IDF

gbk.fit(X_train_tfidf, Y_train)
Y_pred_gbk_tfidf = gbk.predict(X_test_tfidf)
cm_gbk_tfidf = confusion_matrix(Y_test,Y_pred_gbk_tfidf)
gbk_accuracy_tfidf = (cm_gbk_tfidf[0,0]+cm_gbk_tfidf[1,1])/(cm_gbk_tfidf[0,0]+cm_gbk_tfidf[0,1]+cm_gbk_tfidf[1,0]+cm_gbk_tfidf[1,1])
gbk_precision_tfidf = cm_gbk_tfidf[1,1]/(cm_gbk_tfidf[0,1]+cm_gbk_tfidf[1,1])
gbk_recall_tfidf = cm_gbk_tfidf[1,1]/(cm_gbk_tfidf[1,0]+cm_gbk_tfidf[1,1])
gbk_f1_score_tfidf = 2*(gbk_precision_tfidf*gbk_recall_tfidf)/(gbk_precision_tfidf+gbk_recall_tfidf)

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()

# %%
#BOW

decisiontree.fit(X_train_bow, Y_train)
Y_pred_decisiontree_bow = decisiontree.predict(X_test_bow)
cm_decisiontree_bow = confusion_matrix(Y_test,Y_pred_decisiontree_bow)
decisiontree_accuracy_bow = (cm_decisiontree_bow[0,0]+cm_decisiontree_bow[1,1])/(cm_decisiontree_bow[0,0]+cm_decisiontree_bow[0,1]+cm_decisiontree_bow[1,0]+cm_decisiontree_bow[1,1])
decisiontree_precision_bow = cm_decisiontree_bow[1,1]/(cm_decisiontree_bow[0,1]+cm_decisiontree_bow[1,1])
decisiontree_recall_bow = cm_decisiontree_bow[1,1]/(cm_decisiontree_bow[1,0]+cm_decisiontree_bow[1,1])
decisiontree_f1_score_bow = 2*(decisiontree_precision_bow*decisiontree_recall_bow)/(decisiontree_precision_bow+decisiontree_recall_bow)

# %%
#TF-IDF

decisiontree.fit(X_train_tfidf, Y_train)
Y_pred_decisiontree_tfidf = decisiontree.predict(X_test_tfidf)
cm_decisiontree_tfidf = confusion_matrix(Y_test,Y_pred_decisiontree_tfidf)
decisiontree_accuracy_tfidf = (cm_decisiontree_tfidf[0,0]+cm_decisiontree_tfidf[1,1])/(cm_decisiontree_tfidf[0,0]+cm_decisiontree_tfidf[0,1]+cm_decisiontree_tfidf[1,0]+cm_decisiontree_tfidf[1,1])
decisiontree_precision_tfidf = cm_decisiontree_tfidf[1,1]/(cm_decisiontree_tfidf[0,1]+cm_decisiontree_tfidf[1,1])
decisiontree_recall_tfidf = cm_decisiontree_tfidf[1,1]/(cm_decisiontree_tfidf[1,0]+cm_decisiontree_tfidf[1,1])
decisiontree_f1_score_tfidf = 2*(decisiontree_precision_tfidf*decisiontree_recall_tfidf)/(decisiontree_precision_tfidf+decisiontree_recall_tfidf)

# %%
#RANDOMFOREST

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
#BOW

rf.fit(X_train_bow, Y_train)
Y_pred_rf_bow = rf.predict(X_test_bow)
cm_rf_bow = confusion_matrix(Y_test,Y_pred_rf_bow)
rf_accuracy_bow = (cm_rf_bow[0,0]+cm_rf_bow[1,1])/(cm_rf_bow[0,0]+cm_rf_bow[0,1]+cm_rf_bow[1,0]+cm_rf_bow[1,1])
rf_precision_bow = cm_rf_bow[1,1]/(cm_rf_bow[0,1]+cm_rf_bow[1,1])
rf_recall_bow = cm_rf_bow[1,1]/(cm_rf_bow[1,0]+cm_rf_bow[1,1])
rf_f1_score_bow = 2*(rf_precision_bow*rf_recall_bow)/(rf_precision_bow+rf_recall_bow)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#TF-IDF

rf.fit(X_train_tfidf, Y_train)
Y_pred_rf_tfidf = rf.predict(X_test_tfidf)
cm_rf_tfidf = confusion_matrix(Y_test,Y_pred_rf_tfidf)
rf_accuracy_tfidf = (cm_rf_tfidf[0,0]+cm_rf_tfidf[1,1])/(cm_rf_tfidf[0,0]+cm_rf_tfidf[0,1]+cm_rf_tfidf[1,0]+cm_rf_tfidf[1,1])
rf_precision_tfidf = cm_rf_tfidf[1,1]/(cm_rf_tfidf[0,1]+cm_rf_tfidf[1,1])
rf_recall_tfidf = cm_rf_tfidf[1,1]/(cm_rf_tfidf[1,0]+cm_rf_tfidf[1,1])
rf_f1_score_tfidf = 2*(rf_precision_tfidf*rf_recall_tfidf)/(rf_precision_tfidf+rf_recall_tfidf)

# %%
#BOW Metrics

metrics_bow = [ (LR_accuracy_bow, LR_precision_bow, LR_recall_bow, LR_f1_score_bow) ,
                (nb_accuracy_bow, nb_precision_bow, nb_recall_bow, nb_f1_score_bow) ,
                (nn_accuracy_bow, nn_precision_bow, nn_recall_bow, nn_f1_score_bow) ,
                (gbk_accuracy_bow, gbk_precision_bow, gbk_recall_bow, gbk_f1_score_bow) ,
                (decisiontree_accuracy_bow, decisiontree_precision_bow, decisiontree_recall_bow, decisiontree_f1_score_bow) ,
                (rf_accuracy_bow, rf_precision_bow, rf_recall_bow, rf_f1_score_bow) ]
               

dfObj_bow = pd.DataFrame(metrics_bow, columns = ['Accuracy' , 'Precision', 'Recall' , 'F1 Score'], 
                     index=['Logistic Regression', 'Naive-Bayes', 'ANN' , 'Gradient Booster' , 'Decision Tree' , 'Random Forest'])

# %%
#TF-IDF Metrics

metrics_tfidf = [ (LR_accuracy_tfidf, LR_precision_tfidf, LR_recall_tfidf, LR_f1_score_tfidf) ,
                (nb_accuracy_tfidf, nb_precision_tfidf, nb_recall_tfidf, nb_f1_score_tfidf) ,
                (nn_accuracy_tfidf, nn_precision_tfidf, nn_recall_tfidf, nn_f1_score_tfidf) ,
                (gbk_accuracy_tfidf, gbk_precision_tfidf, gbk_recall_tfidf, gbk_f1_score_tfidf) ,
                (decisiontree_accuracy_tfidf, decisiontree_precision_tfidf, decisiontree_recall_tfidf, decisiontree_f1_score_tfidf) ,
                (rf_accuracy_tfidf, rf_precision_tfidf, rf_recall_tfidf, rf_f1_score_tfidf) ]
               

dfObj_tfidf = pd.DataFrame(metrics_tfidf, columns = ['Accuracy' , 'Precision', 'Recall' , 'F1 Score'], 
                     index=['Logistic Regression', 'Naive-Bayes', 'ANN' , 'Gradient Booster' , 'Decision Tree' , 'Random Forest'])

# %%
dfObj_bow
# Out:
#                                                               Accuracy  \
# Logistic Regression                                            0.73155
# Naive-Bayes                                                    0.65185
# ANN                  [0.7174, 0.746275, 0.7869, 0.85055, 0.8936, 0....
# Gradient Booster                                              0.696935
# Decision Tree                                                 0.670384
# Random Forest                                                   0.6993
#
#                                                              Precision  \
# Logistic Regression                                           0.728867
# Naive-Bayes              [0.65314057 0.72376004 0.         0.        ]
# ANN                  [0.8123218490183354, 0.8285212968230248, 0.848...
# Gradient Booster                                              0.671609
# Decision Tree                                                 0.707854
# Random Forest                                                 0.726547
#
#                                                                 Recall  \
# Logistic Regression                                           0.835296
# Naive-Bayes              [0.61743425 0.67838484 0.         0.        ]
# ANN                  [0.7229841577410698, 0.7492116731882096, 0.790...
# Gradient Booster                                              0.906482
# Decision Tree                                                 0.708732
# Random Forest                                                 0.749579
#
#                                                               F1 Score
# Logistic Regression                                           0.778461
# Naive-Bayes              [0.63478569 0.70033824 0.         0.        ]
# ANN                  [0.7591081502556801, 0.782227645111084, 0.8138...
# Gradient Booster                                              0.771567
# Decision Tree                                                 0.708293
# Random Forest                                                 0.737884

# %%
dfObj_tfidf
# Out:
#                                                               Accuracy  \
# Logistic Regression                                            0.73005
# Naive-Bayes                                                     0.6459
# ANN                  [0.7159875, 0.73945, 0.7670625, 0.824075, 0.87...
# Gradient Booster                                                0.6939
# Decision Tree                                                 0.671317
# Random Forest                                                   0.7045
#
#                                                              Precision  \
# Logistic Regression                                           0.732633
# Naive-Bayes              [0.63303057 0.7359011  0.         0.        ]
# ANN                  [0.8092584884405136, 0.8251530745267868, 0.835...
# Gradient Booster                                              0.668075
# Decision Tree                                                 0.703318
# Random Forest                                                 0.734349
#
#                                                                 Recall  \
# Logistic Regression                                           0.821837
# Naive-Bayes              [0.65636844 0.63782874 0.         0.        ]
# ANN                  [0.7245069511771202, 0.7422688261032104, 0.771...
# Gradient Booster                                              0.910033
# Decision Tree                                                 0.722813
# Random Forest                                                 0.746834
#
#                                                               F1 Score
# Logistic Regression                                           0.774676
# Naive-Bayes              [0.6444883  0.68336417 0.         0.        ]
# ANN                  [0.7579088297009469, 0.776651143693924, 0.7976...
# Gradient Booster                                              0.770505
# Decision Tree                                                 0.712932
# Random Forest                                                 0.740539
